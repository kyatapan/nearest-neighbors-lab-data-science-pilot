# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up.  It wants to do some initial research on NYC trips.  LiftOff has a theory that the pickup location of a taxi ride can help predict the length of the ride.  So the hypothesis is that trips that have a similar pickup location will have a similar trip length. It wants to target the locations that generally have longer rides, as it makes more money that way.
#
# LiftOff asks us to do some analysis. Lucky for us, information about NYC taxi trips is available on [it's website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ### A little different

# %% [markdown]
# Before we get started, note that our problem here is a little bit different than what we worked with previously.
#
# Before our job would be complete upon finding the closest trips to a given location -- that is, upon finding our nearest neighbors.  Now, we still need to find the closest trips, but then we also need to use this data to predict the length of the trip.  As you'll see, to predict a trip length from a given location, we'll find the trips that occurred nearest to the given location, then take the median of those nearest trips, to make a prediction about trip length.
#
# The second new thing that we'll see with our problem is the task of choosing the correct number of neighbors or trips.  Say we choose the 500 closest neighbors to a given point.  Well in a dataset of only 1000 trips, we would be including trips from all over the map, and our nearest neighbors formula wouldn't tell us too much about how a specific point is different.  However, if we only choose one neighbor at a given point and assume that the one neighbor's trip distance predicts the length of our trip, then we run the risk of that trip just being a special case and not the norm for that area.  So how to choose the correct number of neighbors, referred to as $k$, is something that we'll need to explore.

# %% [markdown]
# ### Exploring and Gathering the Data

# %% [markdown]
# If you go to [NYC Open Data](https://opendata.cityofnewyork.us/), you can find NYC taxi data after a quick search [it's website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n) if you click on the button, "API", you'll find the data that we'll be working with.  For you're reading pleasure, the data has already been moved to the "trips.json" file in this lab.

# %% [markdown]
# ```python
# [
#   {
#     "dropoff_datetime": "2014-11-26T22:31:00.000",
#     "dropoff_latitude": "40.746769999999998",
#     "dropoff_longitude": "-73.997450000000001",
#     "fare_amount": "52",
#     "imp_surcharge": "0",
#     "mta_tax": "0.5",
#     "passenger_count": "1",
#     "payment_type": "CSH",
#     "pickup_datetime": "2014-11-26T21:59:00.000",
#     "pickup_latitude": "40.64499",
#     "pickup_longitude": "-73.781149999999997",
#     "rate_code": "2",
#     "tip_amount": "0",
#     "tolls_amount": "5.3300000000000001",
#     "total_amount": "57.829999999999998",
#     "trip_distance": "18.379999999999999",
#     "vendor_id": "VTS"
#   },
# ...
# ...
# ]
# ```

# %% [markdown]
# ### Document Retrieval

# %% [markdown]
# Now, we like the amount of data, but we don't need all of the attributes provided.  We decide that all we need for this exploration is `pickup_latitude`, and `pickup_longitude`.

# %% [markdown]
# The first step is to load the data from a JSON file, which can be a little tricky in python.  We'll write a function to do it for you - using the pandas library.

# %%
import pandas

def parse_file(fileName):
    trips_df = pandas.read_json(fileName)
    return trips_df.to_dict('records')

trips = parse_file('trips.json')

# %%
trips[0]
# Out:
# {'dropoff_datetime': '2014-11-26T22:31:00.000',
#  'dropoff_latitude': 40.74677,
#  'dropoff_longitude': -73.99745,
#  'fare_amount': 52.0,
#  'imp_surcharge': 0.0,
#  'mta_tax': 0.5,
#  'passenger_count': 1,
#  'payment_type': 'CSH',
#  'pickup_datetime': '2014-11-26T21:59:00.000',
#  'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'rate_code': 2,
#  'store_and_fwd_flag': nan,
#  'tip_amount': 0.0,
#  'tolls_amount': 5.33,
#  'total_amount': 57.83,
#  'trip_distance': 18.38,
#  'vendor_id': 'VTS'}

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Ok, so as you can see from above, the `trips` variable returns an array of dictionaries with each dictionary representing a trip.  Write a function called `parse_trips(trips)` that returns an array of the trips with just the following attributes: `trip_distance`, `pickup_latitude`, `pickup_longitude`.
#
# Run the `index-tests.py` file to ensure that you wrote it correctly.

# %%
def parse_trips(trips):
    parsed_trips = []
    for trip in trips:
        trip_dict = {'trip_distance': trip['trip_distance'],'pickup_latitude': trip['pickup_latitude'], 'pickup_longitude': trip['pickup_longitude']}
        parsed_trips.append(trip_dict)
    return parsed_trips

# %%
parsed_trips = parse_trips(trips)
parsed_trips[0]
    # {'pickup_latitude': 40.64499,
    #  'pickup_longitude': -73.78115,
    #  'trip_distance': 18.38}

len(parsed_trips)
    # 1000


set([key for trip in parsed_trips for key in list(trip.keys())])
    # {'pickup_latitude', 'pickup_longitude', 'trip_distance'}
# Out:
# {'pickup_latitude', 'pickup_longitude', 'trip_distance'}

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's answer some initial questions.  Here is where our data will go.

# %%
import gmplot
gmap = gmplot.GoogleMapPlotter(40.758896, -73.985130, 12)
gmap.draw("mymap.html")

#pip install gmplot
#from gmplot import gmplot
#gmap = gmplot.GoogleMapPlotter(40.758896, -73.985130, 12)
#gmap.draw("my_map.html")

#from gmplot import GoogleMapPlotter as gmp
#gmap = gmp.from_geocode("New York City")
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-6-ad68c92f9197> in <module>()
# ----> 1 import gmplot
#       2 gmap = gmplot.GoogleMapPlotter(40.758896, -73.985130, 12)
#       3 gmap.draw("mymap.html")
#       4
#       5 #pip install gmplot
#
# ModuleNotFoundError: No module named 'gmplot'

# %% [markdown]
# ![](./Manhattan.png)

# %% [markdown]
# Now, plotting the data feeds into the following function.
# ```python
# gmap.plot(latitudes, longitudes, 'cornflowerblue', edge_width=10)
# ```
# So we'll need an array of latitudes, each element representing the latitude of a trip, and an array of longitudes, each representing the longitudes associated with a trip.  Write a function called `trip_latitudes` that given a list of trips returns a list of latitudes, and `trip_longitudes` that given a list of trips, returns a list of `longitudes` accordingly.  Run the file `nearest-neighbor-lab-tests.py` to get feedback.

# %%
def trip_latitudes(trips):
    latitudes_array = list(map(lambda trip: trip['pickup_latitude'], trips))
    return latitudes_array

# %%
def trip_longitudes(trips):
    longitudes_array = list(map(lambda trip: trip['pickup_longitude'], trips))
    return longitudes_array

# %%
latitudes = trip_latitudes(parsed_trips)
longitudes = trip_longitudes(parsed_trips)

# %%
len(latitudes) 
# 1000
# Out:
# 1000

# %%
gmap.plot(latitudes or [], longitudes or [], 'cornflowerblue', edge_width=10)
gmap.draw("myplot.html")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-11-a722beb8f613> in <module>()
# ----> 1 gmap.plot(latitudes or [], longitudes or [], 'cornflowerblue', edge_width=10)
#       2 gmap.draw("myplot.html")
#
# NameError: name 'gmap' is not defined

# %% [markdown]
# Plotting the trips give you the following.

# %% [markdown]
# ![](./map-plotting.png)

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the fare distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
#  First write a method `distance_location` that calculates the distance between two individuals.

# %%
import math

def distance_location(selected_individual, neighbor):
    longitude_diff = selected_individual['pickup_longitude'] - neighbor['pickup_longitude']
    latitude_diff = selected_individual['pickup_latitude'] - neighbor['pickup_latitude']
    distance = (longitude_diff**2 + latitude_diff**2)**0.5
    return distance

# %%
first_trip = parsed_trips[0]
second_trip = parsed_trips[1]

distance_location(first_trip, second_trip) 
    # 0.23505256047318146
# Out:
# 0.23505256047318146

# %% [markdown]
# Write the nearest neighbors formula.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_individual, neighbors, number = 3):
    neighbor_distances = list(map(lambda neighbor: distance_location(selected_individual, neighbor), neighbors))
    nearest_neighbors = neighbors[:]
    for i in range(0, len(neighbor_distances)):
        nearest_neighbors[i]['distance'] = neighbor_distances[i]
    sorted_neighbor_distances = sorted(nearest_neighbors, key=lambda neighbor: neighbor['distance'])
    if sorted_neighbor_distances[0]['distance']==0.0:
        del sorted_neighbor_distances[0]
    return sorted_neighbor_distances[:number]
    
#nearest_neighbors(parsed_trips[1], parsed_trips)

# %%
selected_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}


nearest_neighbors(selected_trip, parsed_trips or [], number = 3)
#parsed_trips
# [{'distance': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'distance': 0.0},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'distance': 0.23505256047318146},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'distance': 0.2162779533470808},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'distance': 0.24242215976473674},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.762912,
#   'pickup_longitude': -73.967782,
#   'distance': 0.22076481039332593},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.731176,
#   'pickup_longitude': -73.991572,
#   'distance': 0.22738831254047148},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.800219,
#   'pickup_longitude': -73.968098,
#   'distance': 0.2429929981398639},
#  {'trip_distance': 17.3,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'distance': 0.0042359798158141185},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.721897,
#   'pickup_longitude': -73.983493,
#   'distance': 0.21646564692347695},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.791566,
#   'pickup_longitude': -73.972224,
#   'distance': 0.24081901347692852},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.744896,
#   'pickup_longitude': -73.978619,
#   'distance': 0.2213034450635568},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.721951,
#   'pickup_longitude': -73.844435,
#   'distance': 0.09963928314676157},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.732382,
#   'pickup_longitude': -74.001682,
#   'distance': 0.23721661975503053},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.768339,
#   'pickup_longitude': -73.961478,
#   'distance': 0.21847920584119773},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.775933,
#   'pickup_longitude': -73.962446,
#   'distance': 0.2236387910560279},
#  {'trip_distance': 9.8,
#   'pickup_latitude': 40.794829,
#   'pickup_longitude': -73.971476,
#   'distance': 0.24223070036021363},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.758647,
#   'pickup_longitude': -73.964878,
#   'distance': 0.21604141184736217},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.713638,
#   'pickup_longitude': -74.011587,
#   'distance': 0.2404449185842875},
#  {'trip_distance': 8.4,
#   'pickup_latitude': 40.77403,
#   'pickup_longitude': -73.874597,
#   'distance': 0.15932251381710127},
#  {'trip_distance': 5.1,
#   'pickup_latitude': 40.728127,
#   'pickup_longitude': -73.99887,
#   'distance': 0.23305312520753735},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.759671,
#   'pickup_longitude': -73.976688,
#   'distance': 0.22668665863918644},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.772651,
#   'pickup_longitude': -73.967095,
#   'distance': 0.22555015838168296},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.770319,
#   'pickup_longitude': -73.960222,
#   'distance': 0.21857296133099804},
#  {'trip_distance': 1.12,
#   'pickup_latitude': 40.720457,
#   'pickup_longitude': -73.988065,
#   'distance': 0.22024778163242495},
#  {'trip_distance': 16.0,
#   'pickup_latitude': 40.754789,
#   'pickup_longitude': -73.973606,
#   'distance': 0.22157421406157182},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.755654,
#   'pickup_longitude': -73.985846,
#   'distance': 0.23269502210403928},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.741568,
#   'pickup_longitude': -73.978341,
#   'distance': 0.21957140197439562},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.736907,
#   'pickup_longitude': -73.98862,
#   'distance': 0.22691966814051334},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.76003,
#   'pickup_longitude': -73.964842,
#   'distance': 0.21674167219065868},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.721366,
#   'pickup_longitude': -74.008287,
#   'distance': 0.2396341172391779},
#  {'trip_distance': 1.97,
#   'pickup_latitude': 40.760147,
#   'pickup_longitude': -73.97627,
#   'distance': 0.22656775818505578},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.745847,
#   'pickup_longitude': -74.001817,
#   'distance': 0.24262328688318888},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.753015,
#   'pickup_longitude': -73.985247,
#   'distance': 0.23092203453547114},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'distance': 0.0011292165425673159},
#  {'trip_distance': 1.17,
#   'pickup_latitude': 40.738767,
#   'pickup_longitude': -74.0086,
#   'distance': 0.2460236334765476},
#  {'trip_distance': 22.8,
#   'pickup_latitude': 40.773797,
#   'pickup_longitude': -73.871065,
#   'distance': 0.15708580608699615},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.743411,
#   'pickup_longitude': -73.97686,
#   'distance': 0.21906413978787692},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.758905,
#   'pickup_longitude': -73.967897,
#   'distance': 0.21874887253194822},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.733877,
#   'pickup_longitude': -73.989602,
#   'distance': 0.22661230123937096},
#  {'trip_distance': 0.95,
#   'pickup_latitude': 40.726162,
#   'pickup_longitude': -73.983432,
#   'distance': 0.21796077882958448},
#  {'trip_distance': 5.88,
#   'pickup_latitude': 40.775122,
#   'pickup_longitude': -73.947765,
#   'distance': 0.21141167339814346},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.75987,
#   'pickup_longitude': -73.978487,
#   'distance': 0.22834032926533512},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.707087,
#   'pickup_longitude': -73.94328,
#   'distance': 0.17361501752153158},
#  {'trip_distance': 1.39,
#   'pickup_latitude': 40.741912,
#   'pickup_longitude': -74.003578,
#   'distance': 0.24262747014302266},
#  {'trip_distance': 11.2,
#   'pickup_latitude': 40.769112,
#   'pickup_longitude': -73.862679,
#   'distance': 0.14850336267236677},
#  {'trip_distance': 2.56,
#   'pickup_latitude': 40.785807,
#   'pickup_longitude': -73.976387,
#   'distance': 0.2407216518263404},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.7513,
#   'pickup_longitude': -73.986852,
#   'distance': 0.23154940920676315},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.733385,
#   'pickup_longitude': -73.987204,
#   'distance': 0.22421402039346996},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.760257,
#   'pickup_longitude': -73.976186,
#   'distance': 0.22655136853482336},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.741249,
#   'pickup_longitude': -74.005201,
#   'distance': 0.24385373829818963},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.985352,
#   'distance': 0.23426191502035304},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756636,
#   'pickup_longitude': -73.9697,
#   'distance': 0.2191253792147375},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.73925,
#   'pickup_longitude': -74.000759,
#   'distance': 0.23898338955040813},
#  {'trip_distance': 1.07,
#   'pickup_latitude': 40.751055,
#   'pickup_longitude': -73.97607,
#   'distance': 0.22190896923063805},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.723584,
#   'pickup_longitude': -73.995992,
#   'distance': 0.2287664787507171},
#  {'trip_distance': 14.43,
#   'pickup_latitude': 40.757037,
#   'pickup_longitude': -73.929485,
#   'distance': 0.1858972900125233},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.743385,
#   'pickup_longitude': -73.981978,
#   'distance': 0.2236368967970206},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.737486,
#   'pickup_longitude': -73.978153,
#   'distance': 0.2176366054343872},
#  {'trip_distance': 1.76,
#   'pickup_latitude': 40.77225,
#   'pickup_longitude': -73.95285,
#   'distance': 0.21371943664533735},
#  {'trip_distance': 2.45,
#   'pickup_latitude': 40.732882,
#   'pickup_longitude': -73.981975,
#   'distance': 0.21921606758858478},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.774567,
#   'pickup_longitude': -73.988232,
#   'distance': 0.24428089088792698},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.757437,
#   'pickup_longitude': -73.964735,
#   'distance': 0.2152853456090395},
#  {'trip_distance': 2.14,
#   'pickup_latitude': 40.789637,
#   'pickup_longitude': -73.975402,
#   'distance': 0.24219123459159708},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.754317,
#   'pickup_longitude': -73.992548,
#   'distance': 0.2379947632470118},
#  {'trip_distance': 0.44,
#   'pickup_latitude': 40.745007,
#   'pickup_longitude': -73.998627,
#   'distance': 0.23937344426231005},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.734982,
#   'pickup_longitude': -73.990523,
#   'distance': 0.22789386387746413},
#  {'trip_distance': 1.95,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.738617,
#   'pickup_longitude': -73.989672,
#   'distance': 0.2285769883715342},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.790712,
#   'pickup_longitude': -73.972809,
#   'distance': 0.24076559879891543},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.750167,
#   'pickup_longitude': -73.987398,
#   'distance': 0.23151768578879758},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.732141,
#   'pickup_longitude': -73.98447,
#   'distance': 0.2212110286604215},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765758,
#   'pickup_longitude': -73.994847,
#   'distance': 0.24546143817919336},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.792594,
#   'pickup_longitude': -73.964102,
#   'distance': 0.23507100016803525},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.762908,
#   'pickup_longitude': -73.969549,
#   'distance': 0.22225849348225643},
#  {'trip_distance': 4.85,
#   'pickup_latitude': 40.750722,
#   'pickup_longitude': -73.968447,
#   'distance': 0.2150800363422906},
#  {'trip_distance': 5.09,
#   'pickup_latitude': 40.769887,
#   'pickup_longitude': -73.86443,
#   'distance': 0.15011601849569428},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.77247,
#   'pickup_longitude': -73.982419,
#   'distance': 0.23824432996610465},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.764545,
#   'pickup_longitude': -73.982668,
#   'distance': 0.23431368365719166},
#  {'trip_distance': 16.63,
#   'pickup_latitude': 40.641805,
#   'pickup_longitude': -73.78641,
#   'distance': 0.006149132052581531},
#  {'trip_distance': 0.79,
#   'pickup_latitude': 40.75224,
#   'pickup_longitude': -73.97835,
#   'distance': 0.22447806685732974},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.758835,
#   'pickup_longitude': -73.988555,
#   'distance': 0.23659568476623366},
#  {'trip_distance': 2.04,
#   'pickup_latitude': 40.722785,
#   'pickup_longitude': -73.988558,
#   'distance': 0.22151781077150584},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.720338,
#   'pickup_longitude': -73.993645,
#   'distance': 0.22545830241754564},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.72973,
#   'pickup_longitude': -73.991628,
#   'distance': 0.22689613501336778},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.958405,
#   'distance': 0.21153841100140727},
#  {'trip_distance': 1.34,
#   'pickup_latitude': 40.756227,
#   'pickup_longitude': -73.98314,
#   'distance': 0.23059408116646082},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.751555,
#   'pickup_longitude': -73.992905,
#   'distance': 0.2370575441744035},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.71333,
#   'pickup_longitude': -74.004106,
#   'distance': 0.23319462587289244},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.764762,
#   'pickup_longitude': -73.991849,
#   'distance': 0.24236212696087986},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.763353,
#   'pickup_longitude': -73.985259,
#   'distance': 0.23594550991701782},
#  {'trip_distance': 0.66,
#   'pickup_latitude': 40.775292,
#   'pickup_longitude': -73.982082,
#   'distance': 0.23948336023198694},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.779515,
#   'pickup_longitude': -73.984852,
#   'distance': 0.24411366292979952},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.768322,
#   'pickup_longitude': -73.982234,
#   'distance': 0.23589310562202312},
#  {'trip_distance': 6.52,
#   'pickup_latitude': 40.766602,
#   'pickup_longitude': -73.95388,
#   'distance': 0.21124661285805324},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.763684,
#   'pickup_longitude': -73.981214,
#   'distance': 0.232623880399237},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.793086,
#   'pickup_longitude': -73.952092,
#   'distance': 0.22617159985285412},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.773602,
#   'pickup_longitude': -73.871055,
#   'distance': 0.15692022039558665},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.771909,
#   'pickup_longitude': -73.959023,
#   'distance': 0.21851141089197632},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.774029,
#   'pickup_longitude': -73.961478,
#   'distance': 0.22174140593267813},
#  {'trip_distance': 0.48,
#   'pickup_latitude': 40.74964,
#   'pickup_longitude': -73.972212,
#   'distance': 0.21784469317383143},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.771542,
#   'pickup_longitude': -73.959533,
#   'distance': 0.2187142048267509},
#  {'trip_distance': 3.89,
#   'pickup_latitude': 40.694095,
#   'pickup_longitude': -73.9839,
#   'distance': 0.2086117530845358},
#  {'trip_distance': 6.98,
#   'pickup_latitude': 40.756312,
#   'pickup_longitude': -73.994315,
#   'distance': 0.2404826499126326},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.730282,
#   'pickup_longitude': -74.006652,
#   'distance': 0.24109308838704416},
#  {'trip_distance': 0.97,
#   'pickup_latitude': 40.777707,
#   'pickup_longitude': -73.955068,
#   'distance': 0.218772193875273},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.726087,
#   'pickup_longitude': -73.994962,
#   'distance': 0.22867508555372143},
#  {'trip_distance': 4.25,
#   'pickup_latitude': 40.738385,
#   'pickup_longitude': -73.999885,
#   'distance': 0.23783949682507385},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.7678,
#   'pickup_longitude': -73.961987,
#   'distance': 0.21859624120510202},
#  {'trip_distance': 0.12,
#   'pickup_latitude': 40.742682,
#   'pickup_longitude': -73.972513,
#   'distance': 0.21485698646542573},
#  {'trip_distance': 1.02,
#   'pickup_latitude': 40.770602,
#   'pickup_longitude': -73.982262,
#   'distance': 0.23711687221284533},
#  {'trip_distance': 2.39,
#   'pickup_latitude': 40.747967,
#   'pickup_longitude': -73.976727,
#   'distance': 0.22103082467837062},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.742803,
#   'pickup_longitude': -74.004093,
#   'distance': 0.2434562881052793},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.755521,
#   'pickup_longitude': -73.97546,
#   'distance': 0.22354748502499638},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.760528,
#   'pickup_longitude': -74.002757,
#   'distance': 0.24991737013061496},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.740732,
#   'pickup_longitude': -74.005513,
#   'distance': 0.2439370540385343},
#  {'trip_distance': 1.11,
#   'pickup_latitude': 40.735497,
#   'pickup_longitude': -74.00601,
#   'distance': 0.24239128831087028},
#  {'trip_distance': 6.01,
#   'pickup_latitude': 40.715387,
#   'pickup_longitude': -74.013518,
#   'distance': 0.2427974979957655},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.721587,
#   'pickup_longitude': -73.995427,
#   'distance': 0.22755600000440362},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance': 0.23278046823778556},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.740332,
#   'pickup_longitude': -73.986289,
#   'distance': 0.22621252459800165},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.7455,
#   'pickup_longitude': -73.977834,
#   'distance': 0.2208774681944762},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.733125,
#   'pickup_longitude': -73.987273,
#   'distance': 0.22417508638116398},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.752092,
#   'pickup_longitude': -73.989949,
#   'distance': 0.23466542311341715},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.72381,
#   'pickup_longitude': -73.992617,
#   'distance': 0.22567871961928446},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.767446,
#   'pickup_longitude': -73.984105,
#   'distance': 0.23703629249758587},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.800479,
#   'pickup_longitude': -73.968083,
#   'distance': 0.24314764158839683},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.717055,
#   'pickup_longitude': -73.991325,
#   'distance': 0.22218662167196992},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.748863,
#   'pickup_longitude': -73.992155,
#   'distance': 0.23518654330977373},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.80474,
#   'pickup_longitude': -73.9478,
#   'distance': 0.23085121832037664},
#  {'trip_distance': 1.23,
#   'pickup_latitude': 40.762202,
#   'pickup_longitude': -73.969015,
#   'distance': 0.2214315044635729},
#  {'trip_distance': 5.19,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.740407,
#   'pickup_longitude': -73.987223,
#   'distance': 0.22709135874797393},
#  {'trip_distance': 5.6,
#   'pickup_latitude': 40.722399,
#   'pickup_longitude': -73.997097,
#   'distance': 0.22940196182683445},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.747572,
#   'pickup_longitude': -73.974092,
#   'distance': 0.21851700640453697},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.794651,
#   'pickup_longitude': -73.972048,
#   'distance': 0.24257052855819514},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.751087,
#   'pickup_longitude': -73.9716,
#   'distance': 0.21800866016972595},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.719886,
#   'pickup_longitude': -74.009981,
#   'distance': 0.24077590696953086},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.760887,
#   'pickup_longitude': -73.98696,
#   'distance': 0.23619879489319817},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.727514,
#   'pickup_longitude': -74.0073,
#   'distance': 0.2407364390282488},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.774453,
#   'pickup_longitude': -73.872166,
#   'distance': 0.1582547965307915},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.741907,
#   'pickup_longitude': -74.003545,
#   'distance': 0.24259522030329075},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.735118,
#   'pickup_longitude': -73.97979,
#   'distance': 0.21813047926412987},
#  {'trip_distance': 8.73,
#   'pickup_latitude': 40.773907,
#   'pickup_longitude': -73.871275,
#   'distance': 0.15729624443705073},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.758937,
#   'pickup_longitude': -73.994232,
#   'distance': 0.24163579522289472},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.752144,
#   'pickup_longitude': -73.977199,
#   'distance': 0.2234215524899089},
#  {'trip_distance': 0.61,
#   'pickup_latitude': 40.745642,
#   'pickup_longitude': -73.990757,
#   'distance': 0.23252079380778312},
#  {'trip_distance': 1.92,
#   'pickup_latitude': 40.71879,
#   'pickup_longitude': -73.98984,
#   'distance': 0.22135481946413899},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.739945,
#   'pickup_longitude': -74.006124,
#   'distance': 0.24419204061762775},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.777575,
#   'pickup_longitude': -73.986287,
#   'distance': 0.24425390681420603},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.753632,
#   'pickup_longitude': -73.988899,
#   'distance': 0.23444131710303018},
#  {'trip_distance': 3.61,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.97703,
#   'distance': 0.22100328051863977},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.769822,
#   'pickup_longitude': -73.960596,
#   'distance': 0.2185952770304038},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.724658,
#   'pickup_longitude': -73.997131,
#   'distance': 0.2302059568842635},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.758345,
#   'pickup_longitude': -73.989398,
#   'distance': 0.2371003701578693},
#  {'trip_distance': 0.55,
#   'pickup_latitude': 40.764807,
#   'pickup_longitude': -73.97669,
#   'distance': 0.22932946842698315},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.772847,
#   'pickup_longitude': -73.962703,
#   'distance': 0.22205608358701326},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793682,
#   'pickup_longitude': -73.966972,
#   'distance': 0.23798976143523426},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.760007,
#   'pickup_longitude': -73.97804,
#   'distance': 0.22802320581247626},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.747252,
#   'pickup_longitude': -73.888215,
#   'distance': 0.14805549928659145},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.756392,
#   'pickup_longitude': -73.967522,
#   'distance': 0.21712882809061018},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.763685,
#   'pickup_longitude': -73.977714,
#   'distance': 0.2296212296827195},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.767068,
#   'pickup_longitude': -73.982805,
#   'distance': 0.23572818479978463},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.77596,
#   'pickup_longitude': -73.98728,
#   'distance': 0.24421858610679106},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.739617,
#   'pickup_longitude': -73.984663,
#   'distance': 0.22443665096859935},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.751953,
#   'pickup_longitude': -73.976404,
#   'distance': 0.22263245020661804},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.718635,
#   'pickup_longitude': -74.000952,
#   'distance': 0.23181135698882502},
#  {'trip_distance': 2.67,
#   'pickup_latitude': 40.7331,
#   'pickup_longitude': -73.981375,
#   'distance': 0.21875425190153755},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.77463,
#   'pickup_longitude': -73.96322,
#   'distance': 0.22350842154157013},
#  {'trip_distance': 1.89,
#   'pickup_latitude': 40.753675,
#   'pickup_longitude': -73.984942,
#   'distance': 0.23096235296905676},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.763262,
#   'pickup_longitude': -73.95948,
#   'distance': 0.21398564177065785},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.768895,
#   'pickup_longitude': -73.958237,
#   'distance': 0.21613017973897172},
#  {'trip_distance': 11.5,
#   'pickup_latitude': 40.641375,
#   'pickup_longitude': -73.788935,
#   'distance': 0.008583382200508133},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.745472,
#   'pickup_longitude': -73.98666,
#   'distance': 0.22875968268906452},
#  {'trip_distance': 2.33,
#   'pickup_latitude': 40.707562,
#   'pickup_longitude': -74.004372,
#   'distance': 0.23182604786348632},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.75331,
#   'pickup_longitude': -73.968992,
#   'distance': 0.21683597340847544},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.769545,
#   'pickup_longitude': -73.960554,
#   'distance': 0.21840270886827864},
#  {'trip_distance': 9.37,
#   'pickup_latitude': 40.77411,
#   'pickup_longitude': -73.874625,
#   'distance': 0.15940373278251582},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.720615,
#   'pickup_longitude': -74.009875,
#   'distance': 0.24090302250075454},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.76305,
#   'pickup_longitude': -73.969831,
#   'distance': 0.22257287202397538},
#  {'trip_distance': 18.2,
#   'pickup_latitude': 40.648605,
#   'pickup_longitude': -73.78482,
#   'distance': 0.005151419707228516},
#  {'trip_distance': 2.29,
#   'pickup_latitude': 40.730875,
#   'pickup_longitude': -74.001527,
#   'distance': 0.23652115202239146},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.763843,
#   'pickup_longitude': -73.928025,
#   'distance': 0.18893994081189622},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.759867,
#   'pickup_longitude': -73.97835,
#   'distance': 0.22822043100696238},
#  {'trip_distance': 0.94,
#   'pickup_latitude': 40.77302,
#   'pickup_longitude': -73.982,
#   'distance': 0.23818564902193773},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.767437,
#   'pickup_longitude': -73.980957,
#   'distance': 0.23434185511342837},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.7951,
#   'pickup_longitude': -73.97166,
#   'distance': 0.24254292857141938},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.78045,
#   'pickup_longitude': -73.980198,
#   'distance': 0.2407685982515212},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.777608,
#   'pickup_longitude': -73.956815,
#   'distance': 0.22010389853204207},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.783897,
#   'pickup_longitude': -73.952306,
#   'distance': 0.22043033136344833},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.738437,
#   'pickup_longitude': -73.999686,
#   'distance': 0.23767693431420658},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.766227,
#   'pickup_longitude': -73.980152,
#   'distance': 0.23302404634072219},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.7472,
#   'pickup_longitude': -74.007947,
#   'distance': 0.2487644735668702},
#  {'trip_distance': 1.63,
#   'pickup_latitude': 40.729602,
#   'pickup_longitude': -73.987032,
#   'distance': 0.22259062978481606},
#  {'trip_distance': 1.86,
#   'pickup_latitude': 40.747295,
#   'pickup_longitude': -74.000877,
#   'distance': 0.2423762933003203},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.764276,
#   'pickup_longitude': -73.954283,
#   'distance': 0.2102479143416244},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.717463,
#   'pickup_longitude': -74.005494,
#   'distance': 0.23575955137597557},
#  {'trip_distance': 3.06,
#   'pickup_latitude': 40.756667,
#   'pickup_longitude': -73.967298,
#   'distance': 0.2170779358502405},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.723036,
#   'pickup_longitude': -73.988783,
#   'distance': 0.22181668288251138},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.742832,
#   'pickup_longitude': -73.989064,
#   'distance': 0.22978530927803237},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.759825,
#   'pickup_longitude': -73.970231,
#   'distance': 0.2212209343303668},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.770567,
#   'pickup_longitude': -73.954641,
#   'distance': 0.21416981582379774},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.743565,
#   'pickup_longitude': -73.988827,
#   'distance': 0.22988424685915512},
#  {'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance': 0.23265355838241908},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.725012,
#   'pickup_longitude': -73.995492,
#   'distance': 0.22879251178305815},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.751251,
#   'pickup_longitude': -73.975745,
#   'distance': 0.22171741958178065},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.742522,
#   'pickup_longitude': -73.993292,
#   'distance': 0.23348815641912168},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance': 0.23491624313572484},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.787171,
#   'pickup_longitude': -73.953967,
#   'distance': 0.22378818612697893},
#  {'trip_distance': 0.87,
#   'pickup_latitude': 40.739887,
#   'pickup_longitude': -74.004942,
#   'distance': 0.24308085048601005},
#  {'trip_distance': 2.47,
#   'pickup_latitude': 40.775297,
#   'pickup_longitude': -73.982005,
#   'distance': 0.23942148039389072},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.743232,
#   'pickup_longitude': -73.983751,
#   'distance': 0.2251636199855571},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.757386,
#   'pickup_longitude': -73.987253,
#   'distance': 0.23475797627556513},
#  {'trip_distance': 0.57,
#   'pickup_latitude': 40.749027,
#   'pickup_longitude': -73.98395,
#   'distance': 0.22792879890219692},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.752385,
#   'pickup_longitude': -73.978314,
#   'distance': 0.22451576541748605},
#  {'trip_distance': 4.0,
#   'pickup_latitude': 40.721988,
#   'pickup_longitude': -73.986383,
#   'distance': 0.21920145139346892},
#  {'trip_distance': 1.04,
#   'pickup_latitude': 40.742422,
#   'pickup_longitude': -73.991082,
#   'distance': 0.23143992578637632},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.735396,
#   'pickup_longitude': -73.993911,
#   'distance': 0.2311719878294091},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.749873,
#   'pickup_longitude': -73.991593,
#   'distance': 0.23513123981725467},
#  {'trip_distance': 1.35,
#   'pickup_latitude': 40.779447,
#   'pickup_longitude': -73.962047,
#   'distance': 0.2253938984489153},
#  {'trip_distance': 5.0,
#   'pickup_latitude': 40.730843,
#   'pickup_longitude': -74.00677,
#   'distance': 0.24140240680035258},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.750116,
#   'pickup_longitude': -73.987503,
#   'distance': 0.23158807500603873},
#  {'trip_distance': 5.2,
#   'pickup_latitude': 40.701734,
#   'pickup_longitude': -74.011263,
#   'distance': 0.23700606385702783},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.72635,
#   'pickup_longitude': -73.977049,
#   'distance': 0.21212229444591232},
#  {'trip_distance': 5.5,
#   'pickup_latitude': 40.688702,
#   'pickup_longitude': -73.98921,
#   'distance': 0.2126022166958785},
#  {'trip_distance': 1.49,
#   'pickup_latitude': 40.771385,
#   'pickup_longitude': -73.96467,
#   'distance': 0.22283466163279245},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.715884,
#   'pickup_longitude': -73.959979,
#   'distance': 0.19236883967265345},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.790046,
#   'pickup_longitude': -73.975066,
#   'distance': 0.24216659181645936},
#  {'trip_distance': 1.44,
#   'pickup_latitude': 40.76418,
#   'pickup_longitude': -73.97822,
#   'distance': 0.23031031457579013},
#  {'trip_distance': 5.3,
#   'pickup_latitude': 40.76041,
#   'pickup_longitude': -73.987652,
#   'distance': 0.23656891681706674},
#  {'trip_distance': 0.43,
#   'pickup_latitude': 40.745647,
#   'pickup_longitude': -73.978275,
#   'distance': 0.22133706710354584},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793261,
#   'pickup_longitude': -73.940565,
#   'distance': 0.21770951211649775},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.762111,
#   'pickup_longitude': -73.968438,
#   'distance': 0.22089391930291544},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.9969,
#   'distance': 0.2387918300528717},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.74886,
#   'pickup_longitude': -73.988666,
#   'distance': 0.23206005075410846},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.730145,
#   'pickup_longitude': -73.986395,
#   'distance': 0.22220909983617257},
#  {'trip_distance': 6.6,
#   'pickup_latitude': 40.75318,
#   'pickup_longitude': -73.973152,
#   'distance': 0.22038567127651687},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.829557,
#   'pickup_longitude': -73.837699,
#   'distance': 0.19303566222333352},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.743102,
#   'pickup_longitude': -73.973988,
#   'distance': 0.21636186999562454},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.750445,
#   'pickup_longitude': -73.98674,
#   'distance': 0.23105844525790475},
#  {'trip_distance': 8.26,
#   'pickup_latitude': 40.743475,
#   'pickup_longitude': -73.923155,
#   'distance': 0.17281410605039918},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.762752,
#   'pickup_longitude': -73.993035,
#   'distance': 0.24241110096075175},
#  {'trip_distance': 3.02,
#   'pickup_latitude': 40.765577,
#   'pickup_longitude': -73.979713,
#   'distance': 0.23231119115962312},
#  {'trip_distance': 0.98,
#   'pickup_latitude': 40.750027,
#   'pickup_longitude': -73.89876,
#   'distance': 0.1576860281350266},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.751947,
#   'pickup_longitude': -73.986142,
#   'distance': 0.23121747320002015},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.71972,
#   'pickup_longitude': -74.008841,
#   'distance': 0.2396409071527723},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.78079,
#   'pickup_longitude': -73.946522,
#   'distance': 0.213984902233785},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.751607,
#   'pickup_longitude': -73.993449,
#   'distance': 0.23756693812481705},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.745595,
#   'pickup_longitude': -73.988398,
#   'distance': 0.23037599599134284},
#  {'trip_distance': 7.46,
#   'pickup_latitude': 40.72245,
#   'pickup_longitude': -73.98729,
#   'distance': 0.22021296782887773},
#  {'trip_distance': 3.03,
#   'pickup_latitude': 40.702557,
#   'pickup_longitude': -73.93467,
#   'distance': 0.1639583785263808},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.734659,
#   'pickup_longitude': -73.98004,
#   'distance': 0.21816911252742086},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.764774,
#   'pickup_longitude': -73.992049,
#   'distance': 0.2425419445312495},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.723516,
#   'pickup_longitude': -73.985065,
#   'distance': 0.21851237928548395},
#  {'trip_distance': 1.88,
#   'pickup_latitude': 40.781072,
#   'pickup_longitude': -73.983538,
#   'distance': 0.24388360598449446},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.793005,
#   'pickup_longitude': -73.973026,
#   'distance': 0.24233208537253836},
#  {'trip_distance': 5.29,
#   'pickup_latitude': 40.721025,
#   'pickup_longitude': -73.993857,
#   'distance': 0.22588844386998502},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.768497,
#   'pickup_longitude': -73.899785,
#   'distance': 0.1712549043794084},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.80726,
#   'pickup_longitude': -73.954179,
#   'distance': 0.23721422331091302},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.773715,
#   'pickup_longitude': -73.963908,
#   'distance': 0.22354107494821449},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.780082,
#   'pickup_longitude': -73.956843,
#   'distance': 0.2216255371409248},
#  {'trip_distance': 7.4,
#   'pickup_latitude': 40.741824,
#   'pickup_longitude': -73.982933,
#   'distance': 0.22381510816967357},
#  {'trip_distance': 3.12,
#   'pickup_latitude': 40.742112,
#   'pickup_longitude': -74.004672,
#   'distance': 0.2437104170280806},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.725925,
#   'pickup_longitude': -74.007585,
#   'distance': 0.24046472392017015},
#  {'trip_distance': 20.5,
#   'pickup_latitude': 40.645718,
#   'pickup_longitude': -73.776765,
#   'distance': 0.004445020697364217},
#  {'trip_distance': 9.4,
#   'pickup_latitude': 40.718398,
#   'pickup_longitude': -73.994967,
#   'distance': 0.2260673438447106},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.736343,
#   'pickup_longitude': -73.99289,
#   'distance': 0.2306061538836338},
#  {'trip_distance': 17.65,
#   'pickup_latitude': 40.753827,
#   'pickup_longitude': -73.994472,
#   'distance': 0.2394822921491325},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.750693,
#   'pickup_longitude': -73.971834,
#   'distance': 0.2180218155712895},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.745964,
#   'pickup_longitude': -73.991152,
#   'distance': 0.2330162841519909},
#  {'trip_distance': 1.93,
#   'pickup_latitude': 40.740482,
#   'pickup_longitude': -74.004042,
#   'distance': 0.2424862176042192},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 8.74,
#   'pickup_latitude': 40.803842,
#   'pickup_longitude': -73.966812,
#   'distance': 0.24434470763248356},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.797632,
#   'pickup_longitude': -73.969822,
#   'distance': 0.24268643091033923},
#  {'trip_distance': 19.05,
#   'pickup_latitude': 40.645322,
#   'pickup_longitude': -73.776652,
#   'distance': 0.0045102359140052955},
#  {'trip_distance': 0.75,
#   'pickup_latitude': 40.749207,
#   'pickup_longitude': -74.003233,
#   'distance': 0.24532028448132598},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.765548,
#   'pickup_longitude': -73.983683,
#   'distance': 0.23569863693496754},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.760289,
#   'pickup_longitude': -73.931531,
#   'distance': 0.1894948668486909},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.778967,
#   'pickup_longitude': -73.981767,
#   'distance': 0.2412405795425051},
#  {'trip_distance': 3.59,
#   'pickup_latitude': 40.7582,
#   'pickup_longitude': -73.973285,
#   'distance': 0.22300753871787246},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.730709,
#   'pickup_longitude': -73.990504,
#   'distance': 0.22622299679078062},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.7456,
#   'pickup_longitude': -73.97814,
#   'distance': 0.22119546152667885},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.719471,
#   'pickup_longitude': -73.999779,
#   'distance': 0.23096765791340332},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.75619,
#   'pickup_longitude': -73.974282,
#   'distance': 0.22285737462332592},
#  {'trip_distance': 3.08,
#   'pickup_latitude': 40.639542,
#   'pickup_longitude': -73.967915,
#   'distance': 0.1868444431311863},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.78366,
#   'pickup_longitude': -73.97427,
#   'distance': 0.23774924458345234},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.7464,
#   'pickup_longitude': -73.97771,
#   'distance': 0.22117825774700892},
#  {'trip_distance': 3.98,
#   'pickup_latitude': 40.727475,
#   'pickup_longitude': -73.98533,
#   'distance': 0.22021182444410883},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.735015,
#   'pickup_longitude': -74.006024,
#   'distance': 0.2422247231415476},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.754176,
#   'pickup_longitude': -74.04442,
#   'distance': 0.2850134654643588},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.740112,
#   'pickup_longitude': -73.994987,
#   'distance': 0.2340394356791176},
#  {'trip_distance': 2.07,
#   'pickup_latitude': 40.719972,
#   'pickup_longitude': -73.987553,
#   'distance': 0.21960077124865343},
#  {'trip_distance': 2.43,
#   'pickup_latitude': 40.70517,
#   'pickup_longitude': -74.006987,
#   'distance': 0.23371774209289212},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.789142,
#   'pickup_longitude': -73.970472,
#   'distance': 0.23795507724778872},
#  {'trip_distance': 4.72,
#   'pickup_latitude': 40.749115,
#   'pickup_longitude': -73.984182,
#   'distance': 0.22817539010376145},
#  {'trip_distance': 2.15,
#   'pickup_latitude': 40.76443,
#   'pickup_longitude': -73.992037,
#   'distance': 0.24236179643045888},
#  {'trip_distance': 3.5,
#   'pickup_latitude': 40.756477,
#   'pickup_longitude': -73.990472,
#   'distance': 0.23716039056511815},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.746142,
#   'pickup_longitude': -73.984852,
#   'distance': 0.22743401660262397},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.747856,
#   'pickup_longitude': -73.989088,
#   'distance': 0.23199057265328515},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.772615,
#   'pickup_longitude': -73.964789,
#   'distance': 0.22363233877505345},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.761912,
#   'pickup_longitude': -73.975275,
#   'distance': 0.22661701107595703},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.740991,
#   'pickup_longitude': -74.005581,
#   'distance': 0.24410134322040225},
#  {'trip_distance': 3.84,
#   'pickup_latitude': 40.764115,
#   'pickup_longitude': -73.97707,
#   'distance': 0.2292932882249274},
#  {'trip_distance': 16.4,
#   'pickup_latitude': 40.728808,
#   'pickup_longitude': -73.987538,
#   'distance': 0.2227587566584124},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.725511,
#   'pickup_longitude': -73.991953,
#   'distance': 0.2256580072809271},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.768967,
#   'pickup_longitude': -73.954822,
#   'distance': 0.21338289554929088},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.75652,
#   'pickup_longitude': -73.973926,
#   'distance': 0.2227140028736495},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.751217,
#   'pickup_longitude': -73.970895,
#   'distance': 0.21745652566432705},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.779557,
#   'pickup_longitude': -73.977187,
#   'distance': 0.23777885284019848},
#  {'trip_distance': 12.06,
#   'pickup_latitude': 40.771472,
#   'pickup_longitude': -73.8755,
#   'distance': 0.15779613057360375},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.73832,
#   'pickup_longitude': -73.9918,
#   'distance': 0.23039946050284227},
#  {'trip_distance': 19.03,
#   'pickup_latitude': 40.643172,
#   'pickup_longitude': -73.789035,
#   'distance': 0.008091869314319596},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.769387,
#   'pickup_longitude': -73.953623,
#   'distance': 0.21265358999555892},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.731752,
#   'pickup_longitude': -74.000932,
#   'distance': 0.23628747780617598},
#  {'trip_distance': 16.1,
#   'pickup_latitude': 40.745874,
#   'pickup_longitude': -73.991095,
#   'distance': 0.23292592058635747},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.767867,
#   'pickup_longitude': -73.963893,
#   'distance': 0.220212990484216},
#  {'trip_distance': 1.04,
#   'pickup_latitude': 40.766245,
#   'pickup_longitude': -73.98354,
#   'distance': 0.23593322598778418},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.753485,
#   'pickup_longitude': -73.97311,
#   'distance': 0.22049899461222697},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.726597,
#   'pickup_longitude': -73.986165,
#   'distance': 0.2206600386884788},
#  {'trip_distance': 0.59,
#   'pickup_latitude': 40.7446,
#   'pickup_longitude': -73.985232,
#   'distance': 0.22709384585232498},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.756806,
#   'pickup_longitude': -73.969385,
#   'distance': 0.2189411635143142},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.783447,
#   'pickup_longitude': -73.947283,
#   'distance': 0.21626491749241572},
#  {'trip_distance': 6.13,
#   'pickup_latitude': 40.758985,
#   'pickup_longitude': -73.989435,
#   'distance': 0.23743946860200418},
#  {'trip_distance': 17.5,
#   'pickup_latitude': 40.645316,
#   'pickup_longitude': -73.776808,
#   'distance': 0.004354220940644754},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance': 0.23395034039941068},
#  {'trip_distance': 0.65,
#   'pickup_latitude': 40.761322,
#   'pickup_longitude': -73.975755,
#   'distance': 0.22672503225052992},
#  {'trip_distance': 9.61,
#   'pickup_latitude': 40.771097,
#   'pickup_longitude': -73.865913,
#   'distance': 0.15194650906816182},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.760195,
#   'pickup_longitude': -73.967307,
#   'distance': 0.21892149431703573},
#  {'trip_distance': 4.92,
#   'pickup_latitude': 40.73286,
#   'pickup_longitude': -74.00007,
#   'distance': 0.23589638254962528},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.75952,
#   'pickup_longitude': -73.985488,
#   'distance': 0.2342458946150462},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.821517,
#   'pickup_longitude': -73.954177,
#   'distance': 0.24718439363762768},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.734922,
#   'pickup_longitude': -73.990548,
#   'distance': 0.22789314826910134},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.757594,
#   'pickup_longitude': -73.989531,
#   'distance': 0.23685924507394812},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.748042,
#   'pickup_longitude': -73.880385,
#   'distance': 0.1430639714568314},
#  {'trip_distance': 6.04,
#   'pickup_latitude': 40.74957,
#   'pickup_longitude': -73.992772,
#   'distance': 0.2360526366808938},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.759663,
#   'pickup_longitude': -73.981141,
#   'distance': 0.23053480650435332},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.756397,
#   'pickup_longitude': -73.966882,
#   'distance': 0.2165823064633871},
#  {'trip_distance': 1.56,
#   'pickup_latitude': 40.68078,
#   'pickup_longitude': -73.967735,
#   'distance': 0.1899865424839425},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.749994,
#   'pickup_longitude': -73.994031,
#   'distance': 0.23736924859173417},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.801351,
#   'pickup_longitude': -73.961519,
#   'distance': 0.23870848012167187},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.766223,
#   'pickup_longitude': -73.981952,
#   'distance': 0.23456104427846333},
#  {'trip_distance': 2.08,
#   'pickup_latitude': 40.740045,
#   'pickup_longitude': -73.982178,
#   'distance': 0.22236841009685618},
#  {'trip_distance': 6.58,
#   'pickup_latitude': 40.801657,
#   'pickup_longitude': -73.934415,
#   'distance': 0.21916822104037126},
#  {'trip_distance': 5.25,
#   'pickup_latitude': 40.738722,
#   'pickup_longitude': -73.987027,
#   'distance': 0.2262101389261784},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.742172,
#   'pickup_longitude': -74.00809,
#   'distance': 0.24687264879690274},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.775633,
#   'pickup_longitude': -73.98233,
#   'distance': 0.2398770223447902},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.792377,
#   'pickup_longitude': -73.96788,
#   'distance': 0.23788867284719445},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.659956,
#   'pickup_longitude': -73.99842,
#   'distance': 0.2177848343112984},
#  {'trip_distance': 0.78,
#   'pickup_latitude': 40.7655,
#   'pickup_longitude': -73.97585,
#   'distance': 0.22897761921200885},
#  {'trip_distance': 7.4,
#   'pickup_latitude': 40.737997,
#   'pickup_longitude': -73.992069,
#   'distance': 0.2305149162418817},
#  {'trip_distance': 8.8,
#   'pickup_latitude': 40.711467,
#   'pickup_longitude': -73.945825,
#   'distance': 0.17758673135682382},
#  {'trip_distance': 0.1,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 3.63,
#   'pickup_latitude': 40.710822,
#   'pickup_longitude': -74.015592,
#   'distance': 0.24350955543469066},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.763597,
#   'pickup_longitude': -73.97968,
#   'distance': 0.23126128372254923},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.744277,
#   'pickup_longitude': -73.973007,
#   'distance': 0.21602550038826185},
#  {'trip_distance': 6.54,
#   'pickup_latitude': 40.774152,
#   'pickup_longitude': -73.873092,
#   'distance': 0.15854385389538378},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.773736,
#   'pickup_longitude': -73.959905,
#   'distance': 0.22029272012711476},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.740018,
#   'pickup_longitude': -74.005399,
#   'distance': 0.2435527351211643},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.750094,
#   'pickup_longitude': -73.979116,
#   'distance': 0.22413698483740388},
#  {'trip_distance': 2.06,
#   'pickup_latitude': 40.741317,
#   'pickup_longitude': -73.983402,
#   'distance': 0.22401955814839253},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.75885,
#   'pickup_longitude': -73.965817,
#   'distance': 0.2169469992624979},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.687077,
#   'pickup_longitude': -73.990203,
#   'distance': 0.21324744401281587},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.76705,
#   'pickup_longitude': -73.979222,
#   'distance': 0.23266104268656138},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.72257,
#   'pickup_longitude': -73.997073,
#   'distance': 0.22943713371858793},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.77958,
#   'pickup_longitude': -73.957862,
#   'distance': 0.22212968969501573},
#  {'trip_distance': 1.34,
#   'pickup_latitude': 40.7385,
#   'pickup_longitude': -73.9853,
#   'distance': 0.2245469719234703},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.770377,
#   'pickup_longitude': -73.982127,
#   'distance': 0.23688320813853486},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.75906,
#   'pickup_longitude': -73.983681,
#   'distance': 0.23244519969447128},
#  {'trip_distance': 2.24,
#   'pickup_latitude': 40.689827,
#   'pickup_longitude': -73.99235,
#   'distance': 0.21590691644549576},
#  {'trip_distance': 17.55,
#   'pickup_latitude': 40.766367,
#   'pickup_longitude': -73.952442,
#   'distance': 0.20993647942414254},
#  {'trip_distance': 3.08,
#   'pickup_latitude': 40.717302,
#   'pickup_longitude': -73.99898,
#   'distance': 0.22951891914176117},
#  {'trip_distance': 24.55,
#   'pickup_latitude': 40.642817,
#   'pickup_longitude': -73.788912,
#   'distance': 0.008060432556630562},
#  {'trip_distance': 5.1,
#   'pickup_latitude': 40.766804,
#   'pickup_longitude': -73.969071,
#   'distance': 0.2239485495309162},
#  {'trip_distance': 1.18,
#   'pickup_latitude': 40.762317,
#   'pickup_longitude': -73.98593,
#   'distance': 0.23600947720165927},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.734099,
#   'pickup_longitude': -73.999288,
#   'distance': 0.23563658655863404},
#  {'trip_distance': 2.58,
#   'pickup_latitude': 40.770737,
#   'pickup_longitude': -73.957142,
#   'distance': 0.21629954247062572},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.724919,
#   'pickup_longitude': -73.998967,
#   'distance': 0.23201915983383464},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.729687,
#   'pickup_longitude': -73.998358,
#   'distance': 0.23313707785978505},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.744083,
#   'pickup_longitude': -73.985687,
#   'distance': 0.2272769390369412},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.726413,
#   'pickup_longitude': -73.977196,
#   'distance': 0.21228221556457327},
#  {'trip_distance': 0.6,
# ...
#   'pickup_longitude': -74.004265,
#   'distance': 0.23137483900589362},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.782011,
#   'pickup_longitude': -73.956252,
#   'distance': 0.222340875335604},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.671487,
#   'pickup_longitude': -73.984354,
#   'distance': 0.204924270463505},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.753034,
#   'pickup_longitude': -73.989329,
#   'distance': 0.23454637489631006},
#  {'trip_distance': 0.81,
#   'pickup_latitude': 40.744997,
#   'pickup_longitude': -73.981732,
#   'distance': 0.22413062881498022},
#  {'trip_distance': 4.11,
#   'pickup_latitude': 40.721882,
#   'pickup_longitude': -73.989213,
#   'distance': 0.22181657204321825},
#  {'trip_distance': 7.6,
#   'pickup_latitude': 40.752342,
#   'pickup_longitude': -73.974746,
#   'distance': 0.22136816193843123},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.709415,
#   'pickup_longitude': -74.008147,
#   'distance': 0.23596232460712607},
#  {'trip_distance': 0.58,
#   'pickup_latitude': 40.755637,
#   'pickup_longitude': -73.96482,
#   'distance': 0.2144234770471797},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.780847,
#   'pickup_longitude': -73.981522,
#   'distance': 0.24208689108045692},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.73668,
#   'pickup_longitude': -73.995368,
#   'distance': 0.2330158956466297},
#  {'trip_distance': 7.8,
#   'pickup_latitude': 40.707517,
#   'pickup_longitude': -74.004445,
#   'distance': 0.2318842011737834},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.73706,
#   'pickup_longitude': -73.99012,
#   'distance': 0.22835355438443086},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.769119,
#   'pickup_longitude': -73.987085,
#   'distance': 0.24045214256895173},
#  {'trip_distance': 2.64,
#   'pickup_latitude': 40.750492,
#   'pickup_longitude': -73.99465,
#   'distance': 0.23814475010799352},
#  {'trip_distance': 11.3,
#   'pickup_latitude': 40.779416,
#   'pickup_longitude': -73.957448,
#   'distance': 0.2217010019824005},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.779454,
#   'pickup_longitude': -73.961831,
#   'distance': 0.22522475675867176},
#  {'trip_distance': 8.12,
#   'pickup_latitude': 40.773952,
#   'pickup_longitude': -73.871235,
#   'distance': 0.15731021794213085},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756805,
#   'pickup_longitude': -73.990317,
#   'distance': 0.23717805150140536},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.766251,
#   'pickup_longitude': -73.98011,
#   'distance': 0.23300066892822238},
#  {'trip_distance': 4.6,
#   'pickup_latitude': 40.747098,
#   'pickup_longitude': -73.98622,
#   'distance': 0.229084588228896},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.774347,
#   'pickup_longitude': -73.963485,
#   'distance': 0.2235604743106504},
#  {'trip_distance': 3.05,
#   'pickup_latitude': 40.73735,
#   'pickup_longitude': -73.988662,
#   'distance': 0.22713784304691137},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.755507,
#   'pickup_longitude': -73.976157,
#   'distance': 0.2241466871002154},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.77734,
#   'pickup_longitude': -73.978578,
#   'distance': 0.23768537541043935},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.730313,
#   'pickup_longitude': -74.00019,
#   'distance': 0.2350713422112602},
#  {'trip_distance': 0.78,
#   'pickup_latitude': 40.770965,
#   'pickup_longitude': -73.964002,
#   'distance': 0.2220462891583601},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.747897,
#   'pickup_longitude': -74.003746,
#   'distance': 0.24523219581654615},
#  {'trip_distance': 3.5,
#   'pickup_latitude': 40.743013,
#   'pickup_longitude': -73.992796,
#   'distance': 0.2332435161906978},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.757036,
#   'pickup_longitude': -73.976146,
#   'distance': 0.22489496688899274},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.75083,
#   'pickup_longitude': -73.990808,
#   'distance': 0.2348586437923928},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.747865,
#   'pickup_longitude': -73.99322,
#   'distance': 0.23570521955399765},
#  {'trip_distance': 1.66,
#   'pickup_latitude': 40.758215,
#   'pickup_longitude': -73.937667,
#   'distance': 0.19317730693330024},
#  {'trip_distance': 2.38,
#   'pickup_latitude': 40.750687,
#   'pickup_longitude': -73.943522,
#   'distance': 0.1937434442581256},
#  {'trip_distance': 1.82,
#   'pickup_latitude': 40.734432,
#   'pickup_longitude': -73.99974,
#   'distance': 0.2361809887861475},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.766799,
#   'pickup_longitude': -73.983307,
#   'distance': 0.2360188236772644},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.752133,
#   'pickup_longitude': -74.004754,
#   'distance': 0.24794832377937964},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.719627,
#   'pickup_longitude': -74.00689,
#   'distance': 0.23775876296995077},
#  {'trip_distance': 12.55,
#   'pickup_latitude': 40.77012,
#   'pickup_longitude': -73.86361,
#   'distance': 0.14985716032275284},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.753714,
#   'pickup_longitude': -73.992042,
#   'distance': 0.23726850579038294},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.779378,
#   'pickup_longitude': -73.97747,
#   'distance': 0.2379110694019939},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.764967,
#   'pickup_longitude': -73.989047,
#   'distance': 0.24003258765842772},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.724772,
#   'pickup_longitude': -73.990509,
#   'distance': 0.22404543825974874},
#  {'trip_distance': 2.18,
#   'pickup_latitude': 40.734817,
#   'pickup_longitude': -73.990455,
#   'distance': 0.2277662682532252},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.751752,
#   'pickup_longitude': -73.990012,
#   'distance': 0.23456653573772876},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.756564,
#   'pickup_longitude': -73.994046,
#   'distance': 0.2403611122706826},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.742736,
#   'pickup_longitude': -74.000354,
#   'distance': 0.2400097375774622},
#  {'trip_distance': 9.7,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.741672,
#   'pickup_longitude': -74.004627,
#   'distance': 0.2434941039388868},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.72597,
#   'pickup_longitude': -73.99738,
#   'distance': 0.23089645579783993},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.743772,
#   'pickup_longitude': -73.992388,
#   'distance': 0.2331938596275718},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.71032,
#   'pickup_longitude': -74.009677,
#   'distance': 0.23768171706927788},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.710885,
#   'pickup_longitude': -74.010269,
#   'distance': 0.23840651666009133},
#  {'trip_distance': 1.46,
#   'pickup_latitude': 40.768567,
#   'pickup_longitude': -73.969685,
#   'distance': 0.22542564440187363},
#  {'trip_distance': 4.19,
#   'pickup_latitude': 40.755322,
#   'pickup_longitude': -73.987748,
#   'distance': 0.23421332974021733},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.750872,
#   'pickup_longitude': -73.993015,
#   'distance': 0.23684969104687797},
#  {'trip_distance': 5.8,
#   'pickup_latitude': 40.691887,
#   'pickup_longitude': -73.982322,
#   'distance': 0.20656597540011276},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 40.753002,
#   'pickup_longitude': -73.996735,
#   'distance': 0.2411296007731161},
#  {'trip_distance': 0.34,
#   'pickup_latitude': 40.765657,
#   'pickup_longitude': -73.970445,
#   'distance': 0.2244841239687116},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.718429,
#   'pickup_longitude': -73.987265,
#   'distance': 0.21880740377327},
#  {'trip_distance': 0.55,
#   'pickup_latitude': 40.75261,
#   'pickup_longitude': -73.978503,
#   'distance': 0.22478939256335487},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.774841,
#   'pickup_longitude': -73.963199,
#   'distance': 0.2236137755193156},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.820267,
#   'pickup_longitude': -73.955068,
#   'distance': 0.24692002238174326},
#  {'trip_distance': 1.98,
#   'pickup_latitude': 40.749905,
#   'pickup_longitude': -73.995245,
#   'distance': 0.23841943345709007},
#  {'trip_distance': 1.55,
#   'pickup_latitude': 40.790222,
#   'pickup_longitude': -73.976825,
#   'distance': 0.24368225099297514},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.751243,
#   'pickup_longitude': -73.993928,
#   'distance': 0.2378322461168808},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.769372,
#   'pickup_longitude': -73.984837,
#   'distance': 0.23866142523038816},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.802452,
#   'pickup_longitude': -73.9623,
#   'distance': 0.24002000738272136},
#  {'trip_distance': 1.13,
#   'pickup_latitude': 40.740012,
#   'pickup_longitude': -73.99121,
#   'distance': 0.23055234564844365},
#  {'trip_distance': 1.79,
#   'pickup_latitude': 40.724477,
#   'pickup_longitude': -73.98706,
#   'distance': 0.2207195307828495},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.649679,
#   'pickup_longitude': -73.804526,
#   'distance': 0.02384164627285503},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.763434,
#   'pickup_longitude': -73.965213,
#   'distance': 0.21887934828348357},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.813836,
#   'pickup_longitude': -73.936919,
#   'distance': 0.2297236450107013},
#  {'trip_distance': 4.4,
#   'pickup_latitude': 40.748613,
#   'pickup_longitude': -73.983003,
#   'distance': 0.22689724488851712},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.756067,
#   'pickup_longitude': -73.990297,
#   'distance': 0.23681336013409593},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.751127,
#   'pickup_longitude': -73.993905,
#   'distance': 0.23775986371547217},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.757541,
#   'pickup_longitude': -73.974641,
#   'distance': 0.22384480043548957},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.783417,
#   'pickup_longitude': -73.951313,
#   'distance': 0.2193569713913848},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.755617,
#   'pickup_longitude': -73.962448,
#   'distance': 0.2123847874330917},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.770837,
#   'pickup_longitude': -73.991015,
#   'distance': 0.24470550797643137},
#  {'trip_distance': 2.55,
#   'pickup_latitude': 40.770932,
#   'pickup_longitude': -73.86622,
#   'distance': 0.15198122339289416},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.742625,
#   'pickup_longitude': -73.995955,
#   'distance': 0.23595292168142074},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.767386,
#   'pickup_longitude': -73.98615,
#   'distance': 0.23875883400619918},
#  {'trip_distance': 1.62,
#   'pickup_latitude': 40.729417,
#   'pickup_longitude': -73.98997,
#   'distance': 0.22524144984660543},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance': 84.23581962219279},
#  {'trip_distance': 3.38,
#   'pickup_latitude': 40.76026,
#   'pickup_longitude': -73.97671,
#   'distance': 0.22700415524831416},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.748453,
#   'pickup_longitude': -73.973209,
#   'distance': 0.21815419283158352},
#  {'trip_distance': 6.5,
#   'pickup_latitude': 40.763605,
#   'pickup_longitude': -73.98895,
#   'distance': 0.2392704708588214},
#  {'trip_distance': 0.81,
#   'pickup_latitude': 40.735872,
#   'pickup_longitude': -74.006705,
#   'distance': 0.24317605957207233},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.761363,
#   'pickup_longitude': -73.969672,
#   'distance': 0.22154733041272012},
#  {'trip_distance': 2.86,
#   'pickup_latitude': 40.661145,
#   'pickup_longitude': -73.997122,
#   'distance': 0.21657536519420512},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.748542,
#   'pickup_longitude': -73.987952,
#   'distance': 0.23127923362897151},
#  {'trip_distance': 3.7,
#   'pickup_latitude': 40.781112,
#   'pickup_longitude': -73.954135,
#   'distance': 0.2201204422787649},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.762465,
#   'pickup_longitude': -73.957122,
#   'distance': 0.21158100200396132},
#  {'trip_distance': 2.27,
#   'pickup_latitude': 40.74805,
#   'pickup_longitude': -74.00412,
#   'distance': 0.24563587787617974},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.780242,
#   'pickup_longitude': -73.959577,
#   'distance': 0.2238957298230586},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.764726,
#   'pickup_longitude': -73.976783,
#   'distance': 0.2293664761577007},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.733294,
#   'pickup_longitude': -74.002744,
#   'distance': 0.23854034722034909},
#  {'trip_distance': 1.08,
#   'pickup_latitude': 40.74976,
#   'pickup_longitude': -73.993847,
#   'distance': 0.23710075223204763},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.753168,
#   'pickup_longitude': -73.969728,
#   'distance': 0.21740317791606237},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.764099,
#   'pickup_longitude': -73.973033,
#   'distance': 0.22584516724960493},
#  {'trip_distance': 6.8,
#   'pickup_latitude': 40.796757,
#   'pickup_longitude': -73.970537,
#   'distance': 0.242694577726818},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765015,
#   'pickup_longitude': -73.976836,
#   'distance': 0.22956265206039758},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.722397,
#   'pickup_longitude': -73.988933,
#   'distance': 0.22173321523398956},
#  {'trip_distance': 1.48,
#   'pickup_latitude': 40.784722,
#   'pickup_longitude': -73.958018,
#   'distance': 0.22540479419923667},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.734082,
#   'pickup_longitude': -74.006202,
#   'distance': 0.24204501062406236},
#  {'trip_distance': 0.56,
#   'pickup_latitude': 40.74772,
#   'pickup_longitude': -73.98274,
#   'distance': 0.22625644963183772},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.774329,
#   'pickup_longitude': -73.988897,
#   'distance': 0.24471900810929964},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.742366,
#   'pickup_longitude': -73.99317,
#   'distance': 0.23331216379778297},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.739342,
#   'pickup_longitude': -74.001677,
#   'distance': 0.2398634145362772},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.756363,
#   'pickup_longitude': -73.985773,
#   'distance': 0.2329689190814931},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.738254,
#   'pickup_longitude': -73.983499,
#   'distance': 0.22280774559471406},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.735046,
#   'pickup_longitude': -73.990119,
#   'distance': 0.227548074254659},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.755857,
#   'pickup_longitude': -73.997045,
#   'distance': 0.2426976363997004},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.772357,
#   'pickup_longitude': -73.960927,
#   'distance': 0.22032276872352616},
#  {'trip_distance': 1.78,
#   'pickup_latitude': 40.775272,
#   'pickup_longitude': -73.95043,
#   'distance': 0.21360973274642817},
#  {'trip_distance': 7.68,
#   'pickup_latitude': 40.763642,
#   'pickup_longitude': -73.988995,
#   'distance': 0.2393278945902501},
#  {'trip_distance': 12.15,
#   'pickup_latitude': 40.768787,
#   'pickup_longitude': -73.862845,
#   'distance': 0.14832319519886364},
#  {'trip_distance': 0.83,
#   'pickup_latitude': 40.772327,
#   'pickup_longitude': -73.952635,
#   'distance': 0.21359264218132767},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.750617,
#   'pickup_longitude': -73.97391,
#   'distance': 0.2198032773390841},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.74049,
#   'pickup_longitude': -73.998152,
#   'distance': 0.23708673097413882},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.759067,
#   'pickup_longitude': -73.977369,
#   'distance': 0.22697016960384928},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance': 0.23305172433603788},
#  {'trip_distance': 9.25,
#   'pickup_latitude': 40.774087,
#   'pickup_longitude': -73.874592,
#   'distance': 0.1593657515685297},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.781736,
#   'pickup_longitude': -73.981283,
#   'distance': 0.2423895340253037},
#  {'trip_distance': 1.46,
#   'pickup_latitude': 40.757812,
#   'pickup_longitude': -73.989042,
#   'distance': 0.23653305762197543},
#  {'trip_distance': 0.53,
#   'pickup_latitude': 40.787172,
#   'pickup_longitude': -73.97763,
#   'distance': 0.2425285787778478}]

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now in working with a nearest neighbors formula, one tricky question is how many neighbors we should use.  Remember that our guess is that trips that have similar pickup locations will have similar lengths of trips.  Then we will just take the median of the trip lengths of this group together to make a prediction.
#
# If we choose too many neighbors, then we'll be averaging together distances from all over town, and we won't really be differentiating between locations.  But if we  look at the trip distances of the three neighbors above, this may be small.  Take a look at the `trip_distances` of the 3 neighbors above.  It's hard to tell if the trip distance of 7 is more typical than the distance of 17.  In other words, our sample size is small.
#
# The choice of the correct number of neighbors is called choosing the correct $k$, as that the variable often assigned to the number of neighbors.  We'll experiment with the our $k$ size throughout the rest of this lab.

# %% [markdown]
# Let's increase the number of our neighbors to see what happens.

# %%
seven_closest = nearest_neighbors(selected_trip, parsed_trips or [], number = 7)
seven_closest
# Out:
# [{'trip_distance': 7.78,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'distance': 0.0004569288784918792},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'distance': 0.0011292165425673159},
#  {'trip_distance': 17.3,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'distance': 0.0042359798158141185},
#  {'trip_distance': 17.5,
#   'pickup_latitude': 40.645316,
#   'pickup_longitude': -73.776808,
#   'distance': 0.004354220940644754},
#  {'trip_distance': 20.5,
#   'pickup_latitude': 40.645718,
#   'pickup_longitude': -73.776765,
#   'distance': 0.004445020697364217},
#  {'trip_distance': 21.44,
#   'pickup_latitude': 40.64534,
#   'pickup_longitude': -73.77668,
#   'distance': 0.004483681523031949},
#  {'trip_distance': 19.05,
#   'pickup_latitude': 40.645322,
#   'pickup_longitude': -73.776652,
#   'distance': 0.0045102359140052955}]

# %% [markdown]
# Notice that most of the data is a distance of .0045 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.  Still, it's hard to know what distance in latitude and longitude really look like, so let's try mapping the data.

# %%
seven_lats = trip_latitudes(seven_closest)
seven_longs = trip_longitudes(seven_closest)

# %%
gmap = gmplot.GoogleMapPlotter(first_trip['pickup_latitude'], first_trip['pickup_longitude'], 15)
gmap.scatter(seven_lats, seven_longs, 'cornflowerblue', edge_width=10)
gmap.draw("nearestneighbors.html")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-20-554ab14d740e> in <module>()
# ----> 1 gmap = gmplot.GoogleMapPlotter(first_trip['pickup_latitude'], first_trip['pickup_longitude'], 15)
#       2 gmap.scatter(seven_lats, seven_longs, 'cornflowerblue', edge_width=10)
#       3 gmap.draw("nearestneighbors.html")
#
# NameError: name 'gmplot' is not defined

# %% [markdown]
# ![](./airportdata.png)

# %% [markdown]
# Well, it looks like we can't really make an assessment of a good $k$ size with this data.  Our location is the airport, which is probably not a very typical place to see if our $k$ size is good for predicting trip lengths.
#
# Let's choose another spot that we expect to be less atypical.  Fifty-first street and 7th Avenue is at $40.761710, -73.982760$.  Now let's again try to see if seven locations is a good spread, but this time starting from midtown.

# %%
midtown_loc = {'pickup_latitude': 40.761710, 'pickup_longitude': -73.982760}
midtown_neighbors = nearest_neighbors(midtown_loc, parsed_trips, number = 7)
list(map(lambda trip: trip['distance'], midtown_neighbors))
# Out:
# [0.00037310588309379025,
#  0.00080072217404248,
#  0.0011555682584735844,
#  0.0012508768924205918,
#  0.0018118976240381972,
#  0.002067074502774709,
#  0.0020684557041472677]

# %% [markdown]
# The distances between neighbors double in size as our $k$ goes from four to five.  How far is this distance really?

# %%
gmap = gmplot.GoogleMapPlotter(midtown_loc['pickup_latitude'], midtown_loc['pickup_longitude'], 15)
closest_lats = trip_latitudes(midtown_neighbors)
closest_longs = trip_longitudes(midtown_neighbors)

gmap.scatter(closest_lats, closest_longs, 'cornflowerblue', edge_width=10)
gmap.draw("nearestmidtown.html")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-22-f2a4017c960e> in <module>()
# ----> 1 gmap = gmplot.GoogleMapPlotter(midtown_loc['pickup_latitude'], midtown_loc['pickup_longitude'], 15)
#       2 closest_lats = trip_latitudes(midtown_neighbors)
#       3 closest_longs = trip_longitudes(midtown_neighbors)
#       4
#       5 gmap.scatter(closest_lats, closest_longs, 'cornflowerblue', edge_width=10)
#
# NameError: name 'gmplot' is not defined

# %% [markdown]
# ![](./midtown.png)

# %% [markdown]
# So essentially this is one or two blocks away from our location of 51st and 7th.  Not too bad.  Looking at the length of the trip for our seven it seems like our neighbor size, $k$, is large enough so we can start to see what would be an expected trip distance.

# %%
midtown_neighbors
# Out:
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance': 0.0020684557041472677}]

# %% [markdown]
# ### Calculating an expected trip distance

# %% [markdown]
# Another way of thinking about the number of neighbors we should choose, is to think the deviation from the median distance.  We want to make sure our number is not so large so that when we choose a location, it just looks like the expected distance across all taxi trips in Manhattan.
#
# Let's write a function called `median_of` that takes a list of trips, and returns the median `trip_distance`.

# %%
import statistics
def median_of(neighbors):
    distances=[]
    distances = list(map(lambda neighbor: neighbor['distance'], neighbors))
    median_value = statistics.median(distances)
    return median_value
    #return sorted_distances[]

# %%
median_of(parsed_trips or [])
# Out:
# 0.023340122764282427

# %% [markdown]
# So when we compare this with our `midtown_neighbors`, we can see that the number is different.  So our number of neighbors is not so large so that we look like the median.

# %%
median_of(midtown_neighbors)
# Out:
# 0.0012508768924205918

# %% [markdown]
# Still, if we begin to change the number of neighbors from seven to ten, our median really starts to change.

# %%
median_of(nearest_neighbors(midtown_loc, parsed_trips, number = 10))
# Out:
# 0.001939486063406453

# %% [markdown]
# Notice however, that between 15 to 20, to 25, our formula begins to give us a similar result.

# %%
median_of(nearest_neighbors(midtown_loc, parsed_trips, number = 25))
# Out:
# 0.0028364923761548875

# %% [markdown]
# So it appears that around 20 could be a sweet spot. Let's try another location to see how we do.

# %%
uws_loc = {'pickup_latitude': 40.786430, 'pickup_longitude': -73.975979}

# %%
median_of(nearest_neighbors(uws_loc, parsed_trips, number = 20))
# Out:
# 0.003112254235318191

# %%
downtown_loc = {'pickup_latitude': 40.713186, 'pickup_longitude': -74.007243}

# %%
median_of(nearest_neighbors(downtown_loc, parsed_trips, number = 20))
# Out:
# 0.005440613736034756

# %% [markdown]
# ### Summary

# %% [markdown]
# Alright, at this point we should be pretty happy as we can make a recommendation to LiftOff.  We can tell LiftOff the neighborhoods in Manhattan that will have the largest expected distance.
